# %% [markdown]
# # 1.Launching

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset=pd.read_csv("general_data.csv")

# %%
dataset.head(5)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  \
# 0          2  Life Sciences              1           1  Female
# 1          1  Life Sciences              1           2  Female
# 2          4          Other              1           3    Male
# 3          5  Life Sciences              1           4    Male
# 4          1        Medical              1           5    Male
#
#            ...           NumCompaniesWorked Over18 PercentSalaryHike  \
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # 2.Data treatment

# %%
dataset.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# 5     False      False           False       False             False
# 6     False      False           False       False             False
# 7     False      False           False       False             False
# 8     False      False           False       False             False
# 9     False      False           False       False             False
# 10    False      False           False       False             False
# 11    False      False           False       False             False
# 12    False      False           False       False             False
# ...

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4380    False
# 4381    False
# 4382    False
# 4383    False
# 4384    False
# 4385    False
# 4386    False
# 4387    False
# 4388    False
# 4389    False
# 4390    False
# 4391    False
# 4392    False
# 4393    False
# 4394    False
# 4395    False
# 4396    False
# 4397    False
# 4398    False
# 4399    False
# 4400    False
# 4401    False
# 4402    False
# 4403    False
# 4404    False
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# ...

# %%
dataset.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# 5      46        No      Travel_Rarely  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 7      29        No      Travel_Rarely  Research & Development
# 8      31        No      Travel_Rarely  Research & Development
# 9      25        No         Non-Travel  Research & Development
# 10     45        No      Travel_Rarely  Research & Development
# 11     36        No      Travel_Rarely  Research & Development
# 12     55        No      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# ...

# %% [markdown]
# # 3.Univariate Analysis

# %%
dataset2 = dataset1[['Age','DistanceFromHome','Education','JobLevel', 'MonthlyIncome','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear','YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager']]

# %%
dataset2
# Out:
#       Age  DistanceFromHome  Education  JobLevel  MonthlyIncome  \
# 0      51                 6          2         1         131160
# 1      31                10          1         1          41890
# 2      32                17          4         4         193280
# 3      38                 2          5         3          83210
# 4      32                10          1         1          23420
# 5      46                 8          3         4          40710
# 6      28                11          2         2          58130
# 7      29                18          3         2          31430
# 8      31                 1          3         3          20440
# 9      25                 7          4         4         134640
# 10     45                17          2         2          79910
# 11     36                28          1         1          33770
# 12     55                14          4         1          55380
# 13     47                 1          1         1          57620
# ...

# %%
dataset2.columns
# Out:
# Index(['Age', 'DistanceFromHome', 'Education', 'JobLevel', 'MonthlyIncome',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset2.describe()
# Out:
#                Age  DistanceFromHome    Education     JobLevel  MonthlyIncome  \
# count  4410.000000       4410.000000  4410.000000  4410.000000    4410.000000
# mean     36.923810          9.192517     2.912925     2.063946   65029.312925
# std       9.133301          8.105026     1.023933     1.106689   47068.888559
# min      18.000000          1.000000     1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000     1.000000   29110.000000
# 50%      36.000000          7.000000     3.000000     2.000000   49190.000000
# 75%      43.000000         14.000000     4.000000     3.000000   83800.000000
# max      60.000000         29.000000     5.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         4391.000000        4410.000000        4401.000000
# mean             2.694830          15.209524          11.279936
# std              2.498887           3.659108           7.782222
# ...

# %%
dataset2.median()
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# JobLevel                       2.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
dataset2.mode()
# Out:
#    Age  DistanceFromHome  Education  JobLevel  MonthlyIncome  \
# 0   35                 2          3         1          23420
#
#    NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# 0                 1.0                 11               10.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      2               5                        0
#
#    YearsWithCurrManager
# 0                     2

# %% [markdown]
# __From the above analysis, we can find that MonthlyIncome has highest Mean,Median and Mode when compared to remaining columns__

# %%
dataset2.kurt()
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# JobLevel                   0.395525
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.007287
# PercentSalaryHike         -0.302638
# TotalWorkingYears          0.912936
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %% [markdown]
# __Kurtosis is highest for YearsAtCompany. So we can say that graph of YearsAtCompany has highest Peak.__

# %%
dataset2.skew()
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# JobLevel                   1.024703
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.026767
# PercentSalaryHike          0.820569
# TotalWorkingYears          1.116832
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %% [markdown]
# __from the above we can see that for all the elements skewness is positive except educatipon__

# %% [markdown]
# # 4.Finding Outlayers

# %%
plt.boxplot(dataset1['Education'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b9552674e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b955267da0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b955267390>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b95526d630>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b95526da58>],
#  'means': []}

# %%
plt.boxplot(dataset1['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b9552c23c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b9552c2c88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b9552c2278>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b9552cd518>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b9552cd940>],
#  'means': []}

# %%
plt.boxplot(dataset1['YearsWithCurrManager'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b955312e48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b95531b748>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b955312cf8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b95531bf98>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b955326400>],
#  'means': []}

# %%
plt.boxplot(dataset1['DistanceFromHome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b955372940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b95537c240>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b9553727f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b95537ca90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b95537ceb8>],
#  'means': []}

# %%
plt.boxplot(dataset1['TrainingTimesLastYear'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b9553cdbe0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b9553d6470>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b9553cda90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b9553d6cc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b9553e0128>],
#  'means': []}

# %%
plt.boxplot(dataset1['JobLevel'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b95542aa20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b955431320>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b95542a8d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b955431b70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b955431f98>],
#  'means': []}

# %%
plt.boxplot(dataset1['YearsAtCompany'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b95548a828>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b955493128>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b95548a6d8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b955493978>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b955493da0>],
#  'means': []}

# %%
plt.boxplot(dataset1['YearsSinceLastPromotion'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b9554eb518>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b9554ebdd8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b9554eb3c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b9554f4668>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b9554f4a90>],
#  'means': []}

# %%
plt.boxplot(dataset1['PercentSalaryHike'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b955542c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b95554e550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b955542b00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b95554edd8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b955556240>],
#  'means': []}

# %%
plt.boxplot(dataset1['MonthlyIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b9555770b8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b955577978>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b95559df28>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b9555af208>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b9555af630>],
#  'means': []}

# %% [markdown]
# __So, from the above plots, we can conclude the following:__
#
# __1)Graphs of Age and Education are normally distributed without any Outliers.__
#
# __2)DistanceFromHome, PercentSalaryHike and Job graphs are Right Skewed without any Outliers.__
#
# __3)MonthlyIncome,YearsAtCompany,YearsSinceLastPromotion and YearsWithCurrManager graphs are right Skewed with many Outliers.__
#
# __4)Graph of TrainingTimesLastYear is normally distributed with many Outliers.__

# %% [markdown]
# # 5.Visualisation

# %% [markdown]
# __Age vs Attrition__

# %%
sns.countplot(x = "Age",hue = "Attrition",data = dataset)

# %% [markdown]
# __DistanceFromHome vs Attrition__

# %%
sns.countplot(x = "DistanceFromHome",hue = "Attrition",data = dataset)

# %% [markdown]
# __Education vs Attrition__

# %%
sns.countplot(x = "Education",hue = "Attrition",data = dataset)

# %% [markdown]
# __JobLevel vs Attrition__

# %%
sns.countplot(x = "JobLevel",hue = "Attrition",data = dataset)

# %% [markdown]
# __NumCompaniesWorkes vs Attrition__

# %%
sns.countplot(x = "NumCompaniesWorked",hue = "Attrition",data = dataset)

# %% [markdown]
# __PercentSalaryHike vs Attrition__

# %%
sns.countplot(x = "PercentSalaryHike",hue = "Attrition",data = dataset)

# %% [markdown]
# __YearsWithCurrManager vs Atrrition__

# %%
sns.countplot(x = "YearsWithCurrManager",hue = "Attrition",data = dataset)

# %% [markdown]
# __YearsAtCompany vs Attrition__

# %%
sns.countplot(x = "YearsAtCompany",hue = "Attrition",data = dataset)

# %% [markdown]
# __MonthlyIncome vs Attrition__

# %%
sns.countplot(x = "MonthlyIncome",hue = "Attrition",data = dataset)

# %% [markdown]
# __TotalWorkingYears vs Attrition__

# %%
sns.countplot(x = "TotalWorkingYears",hue = "Attrition",data = dataset)

# %% [markdown]
# __TrainingTimesLastYear vs Attrition__

# %%
sns.countplot(x = "TrainingTimesLastYear",hue = "Attrition",data = dataset)

# %% [markdown]
# __YearsSinceLastPromotion vs Attrition__

# %%
sns.countplot(x = "YearsSinceLastPromotion",hue = "Attrition",data = dataset)

# %% [markdown]
# # 6.Statistical Test(MannWhitney)

# %%
from scipy.stats import mannwhitneyu

# %%
data1=dataset[dataset["Attrition"] == "Yes"]
data2=dataset[dataset["Attrition"] == "No"]

# %% [markdown]
# __Attrition vs DistanceFromHome__

# %%
stats,p=mannwhitneyu(data1.DistanceFromHome,data2.DistanceFromHome)
print(stats,p)
# Out:
# 1312110.0 0.4629185205822659

# %% [markdown]
# __H0: There is no significant differences in the Distance From Home between attrition (Y) and attirition (N)__
#
# __Ha: There is significant differences in the Distance From Home between attrition (Y) and attirition (N)__
#
# __As the P value of 0.46 is > 0.05, the H0 is accepted and Ha is rejected__

# %% [markdown]
# __Attrition vs MonthlyIncome__

# %%
stats,p=mannwhitneyu(data1.MonthlyIncome,data2.MonthlyIncome)
print(stats,p)
# Out:
# 1264900.5 0.053577283839938566

# %% [markdown]
# __H0: There is no significant differences in the income between attrition (Y) and attirition (N)__
#
# __Ha: There is significant differences in the income between attrition (Y) and attirition (N)__
#
# __H0: There is no significant differences in the Distance From Home between attrition (Y) and attirition (N)__
#
# __Ha: There is significant differences in the Distance From Home between attrition (Y) and attirition (N)__
#
# __As the P value of 0.053 is > 0.05, the H0 is accepted and Ha is rejected__

# %% [markdown]
# __Attrition vs TotalWorkingYears__

# %%
stats,p=mannwhitneyu(data1.TotalWorkingYears,data2.TotalWorkingYears)
print(stats,p)
# Out:
# 909954.0 2.8897554531400447e-39

# %% [markdown]
# __H0: There is no significant differences in the Total Working Years between attrition (Y) and attirition (N)__
#
# __Ha: There is significant differences in the Total Working Years between attrition (Y) and attirition (N)__
#
# __As the P value is again 0.0, which is < than 0.05, the H0 is rejected and ha is accepted__

# %% [markdown]
# __Attrition vs YearsWithCurrManager__

# %%
stats,p=mannwhitneyu(data1.YearsWithCurrManager,data2.YearsWithCurrManager)
print(stats,p)
# Out:
# 957253.5 1.2365483142169853e-31

# %% [markdown]
# __H0: There is no significant differences in the Years With Current Manager between attrition (Y) and attirition (N)__
#
# __Ha: There is significant differences in the Years With Current Manager between attrition (Y) and attirition (N)__
#
# __As the P value is again 0.0, which is < than 0.05, the H0 is rejected and ha is accepted.__

# %% [markdown]
# __Attrition vs YearsAtCompany__

# %%
stats,p=mannwhitneyu(data1.YearsAtCompany,data2.YearsAtCompany)
print(stats,p)
# Out:
# 923238.0 6.047598261692858e-37

# %% [markdown]
# __H0: There is no significant differences in the Years At Company between attrition (Y) and attirition (N)__
#
# __Ha: There is significant differences in the Years At Company between attrition (Y) and attirition (N)__
#
# __As the P value is again 0.0, which is < than 0.05, the H0 is rejected and ha is accepted.__

# %% [markdown]
# # 7.Statistical Test(separate T test)

# %%
from scipy.stats import ttest_ind

# %% [markdown]
# __Attrition vs YearsAtCompany__

# %%
stats,p=ttest_ind(data1.YearsAtCompany,data2.YearsAtCompany)
print(stats,p)
# Out:
# -9.004357011787226 3.163883122491456e-19

# %%
if(p < 0.05):
    print("Reject H0")
else:
    print("Accept H0")
# Out:
# Reject H0

# %% [markdown]
# __H0: There is no significant differences in the Years At Company between attrition (Y) and attirition (N)___
#
# __Ha: There is significant differences in the Years At Company between attrition (Y) and attirition (N)__
#
# __As the P value is again 0.0, which is < than 0.05, the H0 is rejected and ha is accepted.__

# %% [markdown]
# __Attrition vs DistionFromHome__

# %%
stats,p=ttest_ind(data1.DistanceFromHome,data2.DistanceFromHome)
print(stats,p)
# Out:
# -0.6460416038042738 0.518286042805572

# %%
if(p < 0.05):
    print("Reject H0")
else:
    print("Accept H0")
# Out:
# Accept H0

# %% [markdown]
# __H0: There is no significant differences in the Distance From Home between attrition (Y) and attirition (N)__
#
# __Ha: There is significant differences in the Distance From Home between attrition (Y) and attirition (N)__
#
# __As the P value is 0.5, which is > than 0.05, the H0 is accepted and ha is rejected.__

# %% [markdown]
# __Attrition vs MonthlyIncome__

# %%
stats,p=ttest_ind(data1.MonthlyIncome,data2.MonthlyIncome)
print(stats,p)
# Out:
# -2.0708863763619316 0.03842748490605113

# %%
if(p < 0.05):
    print("Reject H0")
else:
    print("Accept H0")
# Out:
# Reject H0

# %% [markdown]
# __H0: There is no significant differences in the Monthly Income between attrition (Y) and attirition (N__)
#
# __Ha: There is significant differences in the Monthly Income between attrition (Y) and attirition (N)__
#
# __As the P value is 0.03, which is < than 0.05, the H0 is rejected and ha is accepted.__

# %% [markdown]
# __Attrition vs YearsWithCurrManager__

# %%
stats,p=ttest_ind(data1.YearsWithCurrManager,data2.YearsWithCurrManager)
print(stats,p)
# Out:
# -10.499379408703438 1.7339322652918153e-25

# %%
if(p < 0.05):
    print("Reject H0")
else:
    print("Accept H0")
# Out:
# Reject H0

# %% [markdown]
# __H0: There is no significant differences in the Years With Current Manager between attrition (Y) and attirition (N)__
#
# __Ha: There is significant differences in the Years With Current Manager between attrition (Y) and attirition (N)__
#
# __As the P value is again 0.0, which is < than 0.05, the H0 is rejected and ha is accepted.__

# %% [markdown]
# # 8)Unsupervised Learning-Correlation Analysis

# %% [markdown]
# __To Find Interdependency of the variables DistanceFrom Home, MonthlyIncome, TotalWorkingYears, YearsAtCompany, YearsWithCurrManager from the Attrition, we did the following Correlation Analysis:__

# %%
from scipy.stats import pearsonr as pr

# %%
d = {'No': 0, 'Yes': 1}
dataset["Attrition"] = dataset['Attrition'].map(d).fillna(dataset['Attrition'])

# %%
dataset['TotalWorkingYears']=dataset['TotalWorkingYears'].fillna(11.28)

# %%
def correlation(stats):
    if(stats < 0 and stats >= -0.6):
        return "Moderate Negative correlation"
    elif(stats == -1):
        return "Perfectly Negative correlation"
    elif(stats == 0):
        return "No correlation"
    elif(stats > 0 and stats <= 0.3):
        return "Low Positive correlation"
    elif(stats > 0.3 and stats <= 0.8):
        return "Highly Positive correlation"
    elif(stats == 1):
        return "Perfectly Positive correlation"

# %%
stats1,p1 = pr(dataset.Attrition,dataset.DistanceFromHome)
print(stats1,p1)
# Out:
# -0.009730141010179659 0.5182860428065224

# %%
stats2,p2 = pr(dataset.Attrition,dataset.MonthlyIncome)
print(stats2,p2)
# Out:
# -0.031176281698115017 0.038427484905971684

# %%
stats3,p3 = pr(dataset.Attrition,dataset.YearsAtCompany)
print(stats3,p3)
# Out:
# -0.13439221398997717 3.16388312248436e-19

# %%
stats4,p4 = pr(dataset.Attrition,dataset.YearsWithCurrManager)
print(stats4,p4)
# Out:
# -0.15619931590162842 1.7339322652874626e-25

# %%
stats5,p5 = pr(dataset.Attrition,dataset.TotalWorkingYears)
print(stats5,p5)
# Out:
# -0.17011136355965176 5.4731597517853375e-30

# %% [markdown]
# __Inference__

# %% [markdown]
# __Attrition and DistanceFromHome__

# %%
print(correlation(stats1))
# Out:
# Moderate Negative correlation

# %% [markdown]
# __As the P value of 0.518 is > 0.05, we are accepting H0 and hence there’s no significant correlation between Attrition & DistanceFromHome__

# %% [markdown]
# __Attrition and MonthlyIncome__

# %%
print(correlation(stats2))
# Out:
# Moderate Negative correlation

# %% [markdown]
# __As the P value of 0.038 is < 0.05, we are accepting Ha and hence there’s significant correlation between Attrition & MonthlyIncome__

# %% [markdown]
# __Attrition and YearsAtCompany__

# %%
print(correlation(stats3))
# Out:
# Moderate Negative correlation

# %% [markdown]
# __As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between Attrition & YearsAtCompany__

# %% [markdown]
# __Attrition and YearsWithCurrManager__

# %%
print(correlation(stats4))
# Out:
# Moderate Negative correlation

# %% [markdown]
# __As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between Attrition & YearsWithCurrManager__

# %% [markdown]
# __Attrition and TotalWorkingYears__

# %%
print(correlation(stats5))
# Out:
# Moderate Negative correlation

# %% [markdown]
# __As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between Attrition & TotalWorkingYears__

# %% [markdown]
# __so we have done a long analysis to conclude that the attrition values are mainly affected by the values of:__
#
# __1.MonthlyIncome__
#
# __2.TotalWorkingYears__
#
# __3.YearsAtCompany__
#
# __4.YearsWithCurrManager__
#
# __So if the company make changes to these attributes then they can definitely lower the attrition values.__
